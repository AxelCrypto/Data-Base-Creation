# %%
# %pip install ipython
# %pip install seaborn
# librerias

import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# para pintar
import pylab as plt
import seaborn as sns

# para que salga el grafico
# %matplotlib inline

from formulas import FirstData
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Actors**

# %%
actors = pd.read_csv("data/actor.csv")


actors = FirstData.first_view(actors)
# Out:
# Dimensiones de df
# (200, 4)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB
# None
# Descripcion
#          actor_id
# count  200.000000
# mean   100.500000
# std     57.879185
# min      1.000000
# 25%     50.750000
# 50%    100.500000
# 75%    150.250000
# max    200.000000
# View of Nulls
#
# Let's lower the cases in columns names.
#
# Let's lower the cases in all the data.
#
# Are their duplicates ? 0
#   actor_id first_name     last_name          last_update
# 0        1   penelope       guiness  2006-02-15 04:34:33
# 1        2       nick      wahlberg  2006-02-15 04:34:33
# ...

# %%
actors.head()
# Out:
#   actor_id first_name     last_name          last_update
# 0        1   penelope       guiness  2006-02-15 04:34:33
# 1        2       nick      wahlberg  2006-02-15 04:34:33
# 2        3         ed         chase  2006-02-15 04:34:33
# 3        4   jennifer         davis  2006-02-15 04:34:33
# 4        5     johnny  lollobrigida  2006-02-15 04:34:33

# %%
actors ['full_name'] = actors.first_name + ' ' + actors.last_name
actors.head()
# Out:
#   actor_id first_name     last_name          last_update            full_name
# 0        1   penelope       guiness  2006-02-15 04:34:33     penelope guiness
# 1        2       nick      wahlberg  2006-02-15 04:34:33        nick wahlberg
# 2        3         ed         chase  2006-02-15 04:34:33             ed chase
# 3        4   jennifer         davis  2006-02-15 04:34:33       jennifer davis
# 4        5     johnny  lollobrigida  2006-02-15 04:34:33  johnny lollobrigida

# %%
#actors.last_update=pd.to_datetime(actors.last_update, format='%Y-%m-%d')

# %%
col_actors = list(actors.columns)

# %% [markdown]
# **category**

# %%
category = pd.read_csv("data/category.csv")


category = FirstData.first_view(category)
# Out:
# Dimensiones de df
# (16, 3)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes
# None
# Descripcion
#        category_id
# count    16.000000
# mean      8.500000
# std       4.760952
# min       1.000000
# 25%       4.750000
# 50%       8.500000
# 75%      12.250000
# max      16.000000
# View of Nulls
#
# Let's lower the cases in columns names.
#
# Let's lower the cases in all the data.
#
# Are their duplicates ? 0
#   category_id         name          last_update
# 0           1       action  2006-02-15 04:46:27
# 1           2    animation  2006-02-15 04:46:27
# 2           3     children  2006-02-15 04:46:27
# ...

# %%
category = category.rename(columns={'name': 'genre'})
col_category = list(category.columns)
category.last_update=pd.to_datetime(category.last_update, format='%Y-%m-%d')

# %%
category.head()
# Out:
#   category_id      genre         last_update
# 0           1     action 2006-02-15 04:46:27
# 1           2  animation 2006-02-15 04:46:27
# 2           3   children 2006-02-15 04:46:27
# 3           4   classics 2006-02-15 04:46:27
# 4           5     comedy 2006-02-15 04:46:27

# %% [markdown]
# **film**

# %%
film = pd.read_csv("data/film.csv")


film = FirstData.first_view(film)
# Out:
# Dimensiones de df
# (1000, 13)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB
# ...

# %%
film.drop(columns = 'original_language_id', inplace = True)

# %%
FirstData.first_view(film)
# Out:
# Dimensiones de df
# (1000, 12)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   object
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   release_year      1000 non-null   object
#  4   language_id       1000 non-null   object
#  5   rental_duration   1000 non-null   object
#  6   rental_rate       1000 non-null   object
#  7   length            1000 non-null   object
#  8   replacement_cost  1000 non-null   object
#  9   rating            1000 non-null   object
#  10  special_features  1000 non-null   object
#  11  last_update       1000 non-null   object
# dtypes: object(12)
# memory usage: 93.9+ KB
# None
# Descripcion
#        film_id             title  \
# count     1000              1000
# unique    1000              1000
# ...

# %%
col_film = list(film.columns)
film.last_update=pd.to_datetime(film.last_update, format='%Y-%m-%d')
film.head()
# Out:
#   film_id             title  \
# 0       1  academy dinosaur
# 1       2    ace goldfinger
# 2       3  adaptation holes
# 3       4  affair prejudice
# 4       5       african egg
#
#                                          description release_year language_id  \
# 0  a epic drama of a feminist and a mad scientist...         2006           1
# 1  a astounding epistle of a database administrat...         2006           1
# 2  a astounding reflection of a lumberjack and a ...         2006           1
# 3  a fanciful documentary of a frisbee and a lumb...         2006           1
# 4  a fast-paced documentary of a pastry chef and ...         2006           1
#
#   rental_duration rental_rate length replacement_cost rating  \
# 0               6        0.99     86            20.99     pg
# 1               3        4.99     48            12.99      g
# 2               7        2.99     50            18.99  nc-17
# 3               5        2.99    117            26.99      g
# ...

# %% [markdown]
# **inventory**

# %%
inventory = pd.read_csv("data/inventory.csv")


inventory = FirstData.first_view(inventory)
# Out:
# Dimensiones de df
# (1000, 4)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB
# None
# Descripcion
#        inventory_id      film_id     store_id
# count   1000.000000  1000.000000  1000.000000
# mean     500.500000   109.866000     1.497000
# std      288.819436    63.862042     0.500241
# min        1.000000     1.000000     1.000000
# 25%      250.750000    56.000000     1.000000
# 50%      500.500000   111.500000     1.000000
# 75%      750.250000   164.000000     2.000000
# max     1000.000000   223.000000     2.000000
# View of Nulls
#
# Let's lower the cases in columns names.
#
# ...

# %%
col_inventory = list(inventory.columns)
inventory.last_update=pd.to_datetime(inventory.last_update, format='%Y-%m-%d')
inventory.head()
# Out:
#   inventory_id film_id store_id         last_update
# 0            1       1        1 2006-02-15 05:09:17
# 1            2       1        1 2006-02-15 05:09:17
# 2            3       1        1 2006-02-15 05:09:17
# 3            4       1        1 2006-02-15 05:09:17
# 4            5       1        2 2006-02-15 05:09:17

# %% [markdown]
# **language**

# %%
language = pd.read_csv("data/language.csv")


language = FirstData.first_view(language)
# Out:
# Dimensiones de df
# (6, 3)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   language_id  6 non-null      int64
#  1   name         6 non-null      object
#  2   last_update  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes
# None
# Descripcion
#        language_id
# count     6.000000
# mean      3.500000
# std       1.870829
# min       1.000000
# 25%       2.250000
# 50%       3.500000
# 75%       4.750000
# max       6.000000
# View of Nulls
#
# Let's lower the cases in columns names.
#
# Let's lower the cases in all the data.
#
# Are their duplicates ? 0
#   language_id      name          last_update
# 0           1   english  2006-02-15 05:02:19
# 1           2   italian  2006-02-15 05:02:19
# 2           3  japanese  2006-02-15 05:02:19
# 3           4  mandarin  2006-02-15 05:02:19
# ...

# %%
language = language.rename(columns = {'name' : 'language'})


col_language = list(language.columns)
language.last_update=pd.to_datetime(language.last_update, format='%Y-%m-%d')

language.head()
# Out:
#   language_id  language         last_update
# 0           1   english 2006-02-15 05:02:19
# 1           2   italian 2006-02-15 05:02:19
# 2           3  japanese 2006-02-15 05:02:19
# 3           4  mandarin 2006-02-15 05:02:19
# 4           5    french 2006-02-15 05:02:19

# %% [markdown]
# **old_HDD**

# %%
old_HDD = pd.read_csv("data/old_HDD.csv")


old_HDD = FirstData.first_view(old_HDD)
# Out:
# Dimensiones de df
# (1000, 5)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    1000 non-null   object
#  1   last_name     1000 non-null   object
#  2   title         1000 non-null   object
#  3   release_year  1000 non-null   int64
#  4   category_id   1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB
# None
# Descripcion
#        release_year  category_id
# count        1000.0  1000.000000
# mean         2006.0     8.355000
# std             0.0     4.726872
# min          2006.0     1.000000
# 25%          2006.0     4.000000
# 50%          2006.0     8.000000
# 75%          2006.0    13.000000
# max          2006.0    16.000000
# View of Nulls
#
# Let's lower the cases in columns names.
#
# Let's lower the cases in all the data.
#
# Are their duplicates ? 0
# ...

# %%
col_old_HDD = list(old_HDD.columns)
old_HDD.release_year=pd.to_datetime(old_HDD.release_year, format='%Y')

old_HDD ['full_name'] = old_HDD.first_name + ' ' + old_HDD.last_name

old_HDD.head()
# Out:
#   first_name last_name                  title release_year category_id  \
# 0   penelope   guiness       academy dinosaur   2006-01-01           6
# 1   penelope   guiness   anaconda confessions   2006-01-01           2
# 2   penelope   guiness            angels life   2006-01-01          13
# 3   penelope   guiness  bulworth commandments   2006-01-01          10
# 4   penelope   guiness          cheaper clyde   2006-01-01          14
#
#           full_name
# 0  penelope guiness
# 1  penelope guiness
# 2  penelope guiness
# 3  penelope guiness
# 4  penelope guiness

# %% [markdown]
# **rental**

# %%
rental = pd.read_csv("data/rental.csv")


rental = FirstData.first_view(rental)
# Out:
# Dimensiones de df
# (1000, 7)
#
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB
# None
# Descripcion
#         rental_id  inventory_id  customer_id     staff_id
# count  1000.00000   1000.000000  1000.000000  1000.000000
# mean    501.18000   2258.179000   296.408000     1.521000
# std     289.19665   1314.667454   172.509319     0.499809
# min       1.00000      2.000000     1.000000     1.000000
# 25%     250.75000   1157.500000   150.000000     1.000000
# ...

# %%
col_rental = list(rental.columns)
rental.last_update=pd.to_datetime(rental.last_update, format='%Y-%m-%d')
rental.rental_date=pd.to_datetime(rental.rental_date, format='%Y-%m-%d')
rental.return_date=pd.to_datetime(rental.return_date, format='%Y-%m-%d')


rental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   object
#  1   rental_date   1000 non-null   datetime64[ns]
#  2   inventory_id  1000 non-null   object
#  3   customer_id   1000 non-null   object
#  4   return_date   1000 non-null   datetime64[ns]
#  5   staff_id      1000 non-null   object
#  6   last_update   1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), object(4)
# memory usage: 54.8+ KB

# %%
rental.head()
# Out:
#   rental_id         rental_date inventory_id customer_id         return_date  \
# 0         1 2005-05-24 22:53:30          367         130 2005-05-26 22:04:30
# 1         2 2005-05-24 22:54:33         1525         459 2005-05-28 19:40:33
# 2         3 2005-05-24 23:03:39         1711         408 2005-06-01 22:12:39
# 3         4 2005-05-24 23:04:41         2452         333 2005-06-03 01:43:41
# 4         5 2005-05-24 23:05:21         2079         222 2005-06-02 04:33:21
#
#   staff_id         last_update
# 0        1 2006-02-15 21:30:53
# 1        1 2006-02-15 21:30:53
# 2        1 2006-02-15 21:30:53
# 3        2 2006-02-15 21:30:53
# 4        1 2006-02-15 21:30:53

# %% [markdown]
# **Union between all**

# %%
actors.head(1)
# Out:
#   actor_id first_name last_name          last_update         full_name
# 0        1   penelope   guiness  2006-02-15 04:34:33  penelope guiness

# %%
category.head(1)
# Out:
#   category_id   genre         last_update
# 0           1  action 2006-02-15 04:46:27

# %%
film.head(1)
# Out:
#   film_id             title  \
# 0       1  academy dinosaur
#
#                                          description release_year language_id  \
# 0  a epic drama of a feminist and a mad scientist...         2006           1
#
#   rental_duration rental_rate length replacement_cost rating  \
# 0               6        0.99     86            20.99     pg
#
#                    special_features         last_update
# 0  deleted scenes,behind the scenes 2006-02-15 05:03:42

# %%
inventory.head(1)
# Out:
#   inventory_id film_id store_id         last_update
# 0            1       1        1 2006-02-15 05:09:17

# %%
language.head(1)
# Out:
#   language_id language         last_update
# 0           1  english 2006-02-15 05:02:19

# %%
old_HDD.head(1)
# Out:
#   first_name last_name             title release_year category_id  \
# 0   penelope   guiness  academy dinosaur   2006-01-01           6
#
#           full_name
# 0  penelope guiness

# %%
rental.head(1)
# Out:
#   rental_id         rental_date inventory_id customer_id         return_date  \
# 0         1 2005-05-24 22:53:30          367         130 2005-05-26 22:04:30
#
#   staff_id         last_update
# 0        1 2006-02-15 21:30:53

# %%
#Objective: Old_HDD as just a multi to multi.
#    1- from the full_name key, import actor_id from actos
#    2- from titles key, import film_id from film
#    3- From categories, passing through category ID, export genre to film.
#    4- Delete columns from Old_HDD which are not actors_id and title_ID.

# %%
old_HDD = old_HDD.merge(actors, on = 'full_name', how='left')
old_HDD = old_HDD.merge(film, on= 'title', how='left')

old_HDD.head(1)
# Out:
#   first_name_x last_name_x             title release_year_x category_id  \
# 0     penelope     guiness  academy dinosaur     2006-01-01           6
#
#           full_name actor_id_x first_name_y last_name_y        last_update_x  \
# 0  penelope guiness          1     penelope     guiness  2006-02-15 04:34:33
#
#   film_id_x                                      description_x release_year_y  \
# 0         1  a epic drama of a feminist and a mad scientist...           2006
#
#   language_id_x rental_duration_x rental_rate_x length_x replacement_cost_x  \
# 0             1                 6          0.99       86              20.99
#
#   rating_x                special_features_x       last_update_y actor_id_y  \
# 0       pg  deleted scenes,behind the scenes 2006-02-15 05:03:42          1
#
#   first_name last_name        last_update_x film_id_y  \
# 0   penelope   guiness  2006-02-15 04:34:33         1
#
#                                        description_y release_year  \
# ...

# %%
list(old_HDD.columns)

to_drop = ['first_name_x',
 'last_name_x',
 'title',
 'release_year_x',
 'full_name',
 'first_name_y',
 'last_name_y',
 'last_update_x',
 'description_x',
 'release_year_y',
 'language_id_x',
 'rental_duration_x',
 'rental_rate_x',
 'length_x',
 'replacement_cost_x',
 'rating_x',
 'special_features_x',
 'last_update_y',
 'actor_id_y',
 'first_name',
 'last_name',
 'last_update_x',
 'film_id_y',
 'description_y',
 'release_year',
 'language_id_y',
 'rental_duration_y',
 'rental_rate_y',
 'length_y',
 'replacement_cost_y',
 'rating_y',
 'special_features_y',
 'last_update_y']

# %%
old_HDD.drop(columns= to_drop, inplace=True)

# %%
old_HDD.head(20)
# Out:
#    category_id actor_id_x film_id_x
# 0            6          1         1
# 1            2          1        23
# 2           13          1        25
# 3           10          1       106
# 4           14          1       140
# 5            4          1       166
# 6           11          1       277
# 7           15          1       361
# 8           10          1       438
# 9            8          1       499
# 10          11          1       506
# 11           3          1       509
# 12           9          1       605
# 13          13          1       635
# 14          11          1       749
# 15           8          1       832
# 16           5          1       939
# 17           4          1       970
# 18          12          1       980
# 19           6          2         3

# %%
old_HDD = old_HDD.merge(category, on= 'category_id', how='left')

# %%
old_HDD = old_HDD.rename(columns = {'actor_id_x' :'actor_id', 'film_id_x' : 'film_id'})

film = film.merge(old_HDD, on= 'film_id', how='left')

# %%
drop = ['category_id', 'actor_id', 'last_update_y']

# %%
film.drop(columns= drop, inplace=True)

# %%
drop = ['category_id', 'genre', 'last_update', ]

# %%
old_HDD.drop(columns = drop, inplace = True)

# %%
actors.drop(columns='full_name',inplace = True )

# %%
film =film.rename(columns = {'last_update_x' : 'last_update'})

# %%
language.columns
# Out:
# Index(['language_id', 'language', 'last_update'], dtype='object')

# %%
#export inventory into rental
# transform language into a multi btwn film and rental

# 1 export language to Rental
# 2 in language import film ID and inventory ID

# %%
inventory.head(1)
# Out:
#   inventory_id film_id store_id         last_update
# 0            1       1        1 2006-02-15 05:09:17

# %%
rental.head(1)
# Out:
#   rental_id         rental_date inventory_id customer_id         return_date  \
# 0         1 2005-05-24 22:53:30          367         130 2005-05-26 22:04:30
#
#   staff_id         last_update
# 0        1 2006-02-15 21:30:53

# %%
rental = rental.merge(inventory, on= 'inventory_id', how='left')

# %%
rental.drop(columns = 'last_update_y',inplace=True)

# %%
inventory.columns
# Out:
# Index(['inventory_id', 'film_id', 'store_id', 'last_update'], dtype='object')

# %%
actors_film =  old_HDD.rename(columns= {'actor_id' : 'actors_actor_id', 'film_id': 'film_film_id' })

# %%
#Borrar foreign keys inutiles en rental:
rental.drop(columns =['customer_id','staff_id', 'store_id'],inplace=True)

# %%
actors_film = actors_film.astype({'actors_actor_id':'int','film_film_id' : 'int' })

# %%
actors_film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   actors_actor_id  1000 non-null   int32
#  1   film_film_id     1000 non-null   int32
# dtypes: int32(2)
# memory usage: 15.6 KB

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1386 entries, 0 to 1385
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1386 non-null   object
#  1   title             1386 non-null   object
#  2   description       1386 non-null   object
#  3   release_year      1386 non-null   object
#  4   language_id       1386 non-null   object
#  5   rental_duration   1386 non-null   object
#  6   rental_rate       1386 non-null   object
#  7   length            1386 non-null   object
#  8   replacement_cost  1386 non-null   object
#  9   rating            1386 non-null   object
#  10  special_features  1386 non-null   object
#  11  last_update       1386 non-null   datetime64[ns]
#  12  genre             1000 non-null   object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 151.6+ KB

# %%
film.drop_duplicates( inplace=True)

# %%
rental = rental.astype({'inventory_id':'int'})
drop = rental.inventory_id[rental.inventory_id >1000].index

# %%
rental.drop(index = drop,inplace =True)
rental.inventory_id[rental.inventory_id >1000].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# # Export to SQL

# %% [markdown]
# dataframes to export:
# - actors
# - actors_film
# - film
# - rental

# %%
# %pip install mysql-connector-python
# %pip install SQLAlchemy
import mysql.connector as conn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with open('mdp.txt') as f: 
    pw = f.readlines()[0]

# %%
# crear una base de datos (vacia)

conexion = conn.connect(host='localhost',
                        user='root',
                        passwd=pw,
                       database='project')  # conexion al servidor

cursor = conexion.cursor()

cursor

# %%
cursor.execute('drop database if exists project;')

cursor.execute('create database project;')

# %%
query = '''

-- MySQL Workbench Forward Engineering

SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;
SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0;
SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';

-- -----------------------------------------------------
-- Schema mydb
-- -----------------------------------------------------
-- -----------------------------------------------------
-- Schema project
-- -----------------------------------------------------

-- -----------------------------------------------------
-- Schema project
-- -----------------------------------------------------
CREATE SCHEMA IF NOT EXISTS `project` DEFAULT CHARACTER SET utf8mb4 COLLATE utf8mb4_0900_ai_ci ;
USE `project` ;

-- -----------------------------------------------------
-- Table `project`.`actors`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `project`.`actors` (
  `actor_id` INT NOT NULL,
  `first_name` TEXT NULL DEFAULT NULL,
  `last_name` TEXT NULL DEFAULT NULL,
  `last_update` TEXT NULL DEFAULT NULL,
  PRIMARY KEY (`actor_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4
COLLATE = utf8mb4_0900_ai_ci;


-- -----------------------------------------------------
-- Table `project`.`film`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `project`.`film` (
  `film_id` INT NOT NULL,
  `title` TEXT NULL DEFAULT NULL,
  `description` TEXT NULL DEFAULT NULL,
  `release_year` TEXT NULL DEFAULT NULL,
  `language_id` TEXT NULL DEFAULT NULL,
  `rental_duration` TEXT NULL DEFAULT NULL,
  `rental_rate` TEXT NULL DEFAULT NULL,
  `length` TEXT NULL DEFAULT NULL,
  `replacement_cost` TEXT NULL DEFAULT NULL,
  `rating` TEXT NULL DEFAULT NULL,
  `special_features` TEXT NULL DEFAULT NULL,
  `last_update` DATETIME NULL DEFAULT NULL,
  `genre` TEXT NULL DEFAULT NULL,
  PRIMARY KEY (`film_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4
COLLATE = utf8mb4_0900_ai_ci;


-- -----------------------------------------------------
-- Table `project`.`actors_film`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `project`.`actors_film` (
  `actors_actor_id` INT NOT NULL,
  `film_film_id` INT NOT NULL,
  PRIMARY KEY (`actors_actor_id`, `film_film_id`),
  INDEX `fk_actors_film_film1_idx` (`film_film_id` ASC) VISIBLE,
  CONSTRAINT `fk_actors_film_actors`
    FOREIGN KEY (`actors_actor_id`)
    REFERENCES `project`.`actors` (`actor_id`),
  CONSTRAINT `fk_actors_film_film1`
    FOREIGN KEY (`film_film_id`)
    REFERENCES `project`.`film` (`film_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4
COLLATE = utf8mb4_0900_ai_ci;


-- -----------------------------------------------------
-- Table `project`.`rental`
-- -----------------------------------------------------
CREATE TABLE IF NOT EXISTS `project`.`rental` (
  `rental_id` INT NOT NULL,
  `rental_date` DATETIME NULL DEFAULT NULL,
  `inventory_id` INT NULL DEFAULT NULL,
  `return_date` DATETIME NULL DEFAULT NULL,
  `last_update_x` DATETIME NULL DEFAULT NULL,
  `film_id` INT NOT NULL,
  PRIMARY KEY (`rental_id`),
  INDEX `fk_rental_film1_idx` (`film_id` ASC) VISIBLE,
  CONSTRAINT `fk_rental_film1`
    FOREIGN KEY (`film_id`)
    REFERENCES `project`.`film` (`film_id`))
ENGINE = InnoDB
DEFAULT CHARACTER SET = utf8mb4
COLLATE = utf8mb4_0900_ai_ci;


SET SQL_MODE=@OLD_SQL_MODE;
SET FOREIGN_KEY_CHECKS=@OLD_FOREIGN_KEY_CHECKS;
SET UNIQUE_CHECKS=@OLD_UNIQUE_CHECKS;

'''

# %%
cursor.execute(query)

# %%
import sqlalchemy 

str_conn = f'mysql+pymysql://root:{pw}@localhost:3306/project'
cursor = sqlalchemy.create_engine(str_conn)

# %%
actors_film.to_sql(name='actors_film', con=cursor, if_exists='replace', index=False)
actors.to_sql(name='actors', con=cursor, if_exists='replace', index=False)
rental.to_sql(name='rental', con=cursor, if_exists='replace', index=False)
film.to_sql(name='film', con=cursor, if_exists='replace', index=False)
# Out:
# 1000
